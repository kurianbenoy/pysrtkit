# %%
1+1
# Out:
# 2

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(SubRipItem)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/pysrtkit/blob/main/pysrtkit/srtfile.py#L53){target="_blank" style="float:right; font-size:smaller"}
#
# ### SubRipItem
#
# >      SubRipItem (index=0, start=None, end=None, text='', position='')
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
#| echo: false
#| output: asis
show_doc(ComparableMixin)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/pysrtkit/blob/main/pysrtkit/srtfile.py#L45){target="_blank" style="float:right; font-size:smaller"}
#
# ### ComparableMixin
#
# >      ComparableMixin ()
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
#| echo: false
#| output: asis
show_doc(SubRipTime)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/pysrtkit/blob/main/pysrtkit/srtfile.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### SubRipTime
#
# >      SubRipTime ()
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
#| echo: false
#| output: asis
show_doc(Error)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/pysrtkit/blob/main/pysrtkit/srtfile.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### Error
#
#
#
# *Common base class for all non-exit exceptions.*

# %%
#| echo: false
#| output: asis
show_doc(InvalidItem)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/pysrtkit/blob/main/pysrtkit/srtfile.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### InvalidItem
#
#
#
# *Common base class for all non-exit exceptions.*

# %%
#| echo: false
#| output: asis
show_doc(SubRipFile)
# Out:
# ---
#
# [source](https://github.com/kurianbenoy/pysrtkit/blob/main/pysrtkit/srtfile.py#L140){target="_blank" style="float:right; font-size:smaller"}
#
# ### SubRipFile
#
# >      SubRipFile (items=None, eol=None, path=None, encoding='utf-8')
#
# *A more or less complete user-defined wrapper around list objects.*

# %%
#| eval: false
subs = SubRipFile.open("/Users/kurianbenoy/Downloads/rahul_kph_vocals_chunk_2.srt")
len(subs)
# Out:
# 39
